# %% [markdown]
# <a href="https://colab.research.google.com/github/pedromorais03/Python-Pandas/blob/main/aula01Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Importando o Pandas

import pandas as pd

combustiveis_df = pd.read_csv("/content/drive/MyDrive/precos-semestrais-ca-2022-01.csv", on_bad_lines='skip')
print(combustiveis_df)
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ...
